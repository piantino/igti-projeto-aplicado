# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.preprocessing import FunctionTransformer

from sklearn.externals import joblib

def load_model(file):
    return joblib.load(file)

features = load_model('../modelos/Features-Leis.pkl')

clf = load_model('../modelos/Modelo-Leis.pkl') 
pipe = Pipeline([
    ('clf', clf)
])

# %%
processos = [
    '0500511-81.2013.8.24.0020', #BUS
    '0028950-35.2012.8.24.0008', #OIG
    '0301154-79.2015.8.24.0011' #BAN
]

# %%
import ipywidgets as widgets

dropdown = widgets.Dropdown(
    options=processos,
    description='Processo:',
    disabled=False,
)
dropdown
# Out:
# Dropdown(description='Processo:', options=('0500511-81.2013.8.24.0020', '0028950-35.2012.8.24.0008', '0301154-…

# %%
import crawler
import leis
import classificador_leis

nomalizador = leis.Leis()

c = crawler.Crawler()
acordaos = c.get_acordaos(dropdown.value)

for acordao in acordaos:
    print('\n{}'.format(acordao['texto']))
    print('\n{}'.format(acordao['ementa']))
    
    leis = nomalizador.get_leis(acordao['ementa'])
    print(leis)
    
    classe = classificador_leis.ClassificadorLeis().classificar(acordao['ementa'])
    print(classe)
# Out:
# Processo: 0301154-79.2015.8.24.0011 (Acórdão)
# Relator: Tulio Pinheiro
# Origem: Brusque
# Orgão Julgador: Terceira Câmara de Direito Comercial
# Julgado em: Thu Oct 18 00:00:00 BRT 2018
# Classe: Embargos de Declaração
#
# ...
